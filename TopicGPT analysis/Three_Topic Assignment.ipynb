# %%
import openai
import pandas as pd
import time

# %%
client = openai.OpenAI(api_key="*** ***")

# %%
df_dialogues = pd.read_csv("../target_behaviour_identification.csv")
df_topics = pd.read_csv("topics_after_deduplication.csv")

# %%
# Construct the topic list text for the prompt
topic_list_text = "\n".join([
    f"{i+1}. {row['Topics']}: {row['Definition']}"
    for i, row in df_topics.iterrows()
])

# %%
# Store results in assignments
assignments = []


# Iterate through each dialogue
for i, row in df_dialogues.iterrows():
    chat_id = row['chat_id']
    dialogue = row['combined_text']

    prompt = f"""You are a topic assignment assistant.

Your task is to assign **one or more** relevant topics from the list below to the given user-AI conversation. 
It is common for a single dialogue to reflect multiple themes. So please consider all possible relevant topics.

For **each assigned topic**, include:
- Topic: the topic name (from the list)
- Quote: one sentence from the dialogue that supports this topic

Only choose from the following topics and definitions:

{topic_list_text}

Now analyze the conversation below.

Dialogue:
---
{dialogue}
---

Respond in the following format. If multiple topics apply, list them all:

Topic: [Topic Name 1]  
Quote: "[Exact quote from the dialogue]"

Topic: [Topic Name 2]  
Quote: "[Exact quote from the dialogue]"

... (as many as needed)
"""

    try:
        response = client.chat.completions.create(
            model="gpt-3.5-turbo",
            messages=[{"role": "user", "content": prompt}],
            temperature=0,
            max_tokens=500
        )
        output = response.choices[0].message.content
        assignments.append({"chat_id": chat_id, "assigned_topics": output})
        print(f"Assigned topics for chat {chat_id}")
        time.sleep(1.2)

    except Exception as e:
        print(f"Error for chat {chat_id}: {e}")
        continue
# Out:
# Assigned topics for chat 1.0
# Assigned topics for chat 2.0
# Assigned topics for chat 3.0
# Assigned topics for chat 4.0
# Assigned topics for chat 5.0
# Assigned topics for chat 6.0
# Assigned topics for chat 7.0
# Assigned topics for chat 8.0
# Assigned topics for chat 9.0
# Assigned topics for chat 10.0
# Assigned topics for chat 11.0
# Assigned topics for chat 12.0
# Assigned topics for chat 13.0
# Assigned topics for chat 14.0
# Assigned topics for chat 15.0
# Assigned topics for chat 16.0
# Assigned topics for chat 17.0
# Assigned topics for chat 18.0
# Assigned topics for chat 19.0
# Assigned topics for chat 21.0
# Assigned topics for chat 22.0
# Assigned topics for chat 23.0
# Assigned topics for chat 24.0
# Assigned topics for chat 25.0
# Assigned topics for chat 26.0
# Assigned topics for chat 27.0
# Assigned topics for chat 28.0
# Assigned topics for chat 29.0
# Assigned topics for chat 31.0
# Assigned topics for chat 32.0
# Assigned topics for chat 33.0
# Assigned topics for chat 36.0
# Assigned topics for chat 37.0
# Assigned topics for chat 38.0
# Assigned topics for chat 39.0
# Assigned topics for chat 40.0
# Assigned topics for chat 41.0
# Assigned topics for chat 42.0
# Assigned topics for chat 43.0
# Assigned topics for chat 44.0
# Assigned topics for chat 45.0
# Assigned topics for chat 48.0
# Assigned topics for chat 49.0
# Assigned topics for chat 50.0
# Assigned topics for chat 51.0
# Assigned topics for chat 52.0
# Assigned topics for chat 53.0
# Assigned topics for chat 55.0
# Assigned topics for chat 56.0
# Assigned topics for chat 57.0
# Assigned topics for chat 58.0
# Assigned topics for chat 59.0
# Assigned topics for chat 60.0
# Assigned topics for chat 61.0
# Assigned topics for chat 62.0
# Assigned topics for chat 63.0
# Assigned topics for chat 64.0
# Assigned topics for chat 65.0
# Assigned topics for chat 66.0
# Assigned topics for chat 67.0
# Assigned topics for chat 69.0
# Assigned topics for chat 70.0
# Assigned topics for chat 71.0
# Assigned topics for chat 72.0
# Assigned topics for chat 73.0
# Assigned topics for chat 74.0
# Assigned topics for chat 75.0
# Assigned topics for chat 76.0
# Assigned topics for chat 80.0
# Assigned topics for chat 81.0
# Assigned topics for chat 83.0
# Assigned topics for chat 84.0
# Assigned topics for chat 85.0
# Assigned topics for chat 86.0
# Assigned topics for chat 87.0
# Assigned topics for chat 88.0
# Assigned topics for chat 89.0
# Assigned topics for chat 90.0
# Assigned topics for chat 91.0
# Assigned topics for chat 92.0
# Assigned topics for chat 93.0
# Assigned topics for chat 94.0
# Assigned topics for chat 95.0
# Assigned topics for chat 96.0
# Assigned topics for chat 98.0
# Assigned topics for chat 99.0
# Assigned topics for chat 100.0
# Assigned topics for chat 101.0
# Assigned topics for chat 102.0
# Assigned topics for chat 103.0
# Assigned topics for chat 104.0
# Assigned topics for chat 105.0
# Assigned topics for chat 106.0
# Assigned topics for chat 107.0
# Assigned topics for chat 108.0
# Assigned topics for chat 109.0
# Assigned topics for chat 110.0
# Assigned topics for chat 111.0
# Assigned topics for chat 112.0
# Assigned topics for chat 113.0
# Assigned topics for chat 114.0
# Assigned topics for chat 115.0
# Assigned topics for chat 116.0
# Assigned topics for chat 117.0
# Assigned topics for chat 118.0
# Assigned topics for chat 120.0
# Assigned topics for chat 121.0
# Assigned topics for chat 122.0
# Assigned topics for chat 123.0
# Assigned topics for chat 124.0
# Assigned topics for chat 125.0
# Assigned topics for chat 126.0
# Assigned topics for chat 127.0
# Assigned topics for chat 129.0
# Assigned topics for chat 130.0
# Assigned topics for chat 131.0
# Assigned topics for chat 132.0
# Assigned topics for chat 133.0
# Assigned topics for chat 135.0
# Assigned topics for chat 136.0
# Assigned topics for chat 137.0
# Assigned topics for chat 138.0
# Assigned topics for chat 140.0
# Assigned topics for chat 141.0
# Assigned topics for chat 144.0
# Assigned topics for chat 145.0
# Assigned topics for chat 146.0
# Assigned topics for chat 147.0
# Assigned topics for chat 148.0
# Assigned topics for chat 149.0
# Assigned topics for chat 150.0
# Assigned topics for chat 151.0
# Assigned topics for chat 152.0
# Assigned topics for chat 153.0
# Assigned topics for chat 156.0
# Assigned topics for chat 157.0
# Assigned topics for chat 158.0
# Assigned topics for chat 160.0
# Assigned topics for chat 161.0
# Assigned topics for chat 162.0
# Assigned topics for chat 165.0
# Assigned topics for chat 167.0
# Assigned topics for chat 168.0
# Assigned topics for chat 170.0
# Assigned topics for chat 171.0
# Assigned topics for chat 172.0
# Assigned topics for chat 175.0
# Assigned topics for chat 176.0
# Assigned topics for chat 177.0
# Assigned topics for chat 178.0
# Assigned topics for chat 179.0
# Assigned topics for chat 181.0
# Assigned topics for chat 182.0
# Assigned topics for chat 183.0
# Assigned topics for chat 186.0
# Assigned topics for chat 188.0
# Assigned topics for chat 189.0
# Assigned topics for chat 190.0
# Assigned topics for chat 191.0
# Assigned topics for chat 192.0

# %%
df_assignments = pd.DataFrame(assignments)

# %%
df_assignments.to_csv("raw_assignments_withQuote.csv", index=False)

# %%
df_assignments.loc[0, 'assigned_topics']
# Out:
# 'Topic: Procrastination  \nQuote: "I want to procrastinate less."\n\nTopic: Self-Reflection  \nQuote: "Please think carefully about my questions and see them primarily as thought impulses that bring you mentally closer to your goal."\n\nTopic: Emotional Well-being  \nQuote: "It sounds like you want a higher quality of life and think that less procrastination could contribute to it."\n\nTopic: Family and Social Relationships  \nQuote: "So you would like to spend more time with your loved ones if you were to procrastinate less."'

# %%
df_assignments.loc[1, 'assigned_topics']
# Out:
# 'Topic: Procrastination  \nQuote: "I see the importance, but I can\'t catch up."\n\nTopic: Goal Setting  \nQuote: "It can be helpful to set smaller, achievable goals."\n\nTopic: Patience  \nQuote: "Stay patient with yourself and celebrate small successes."'

# %%
import re

# Store structured results
topics_assigned = []

for i, row in df_assignments.iterrows():
    chat_id = row['chat_id']
    text = row['assigned_topics']

    # Use regular expression to extract Topic and corresponding Quote
    topic_blocks = re.findall(r"Topic:\s*(.*?)\s*Quote:", text, re.DOTALL)
    
    for topic in topic_blocks:
        topic_clean = topic.strip().replace('"', '')
        if topic_clean:
            topics_assigned.append({
                "chat_id": chat_id,
                "topic": topic_clean
            })

# Convert to DataFrame
topics_assigned = pd.DataFrame(topics_assigned)

# Save as CSV
topics_assigned.to_csv("topics_assigned.csv", index=False)

print(f"Done! Parsed {len(df_topics)} topic assignments.")
# Out:
# Done! Parsed 498 topic assignments.
