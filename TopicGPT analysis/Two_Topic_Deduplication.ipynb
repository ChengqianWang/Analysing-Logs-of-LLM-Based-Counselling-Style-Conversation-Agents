# %%
import pandas as pd
from sentence_transformers import SentenceTransformer
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# %%
df = pd.read_csv("generated_topics.csv")

# %% [markdown]
# #### Combine *Topics* and *Definition* columns into the new *text* column

# %%
df['text'] = df['Topics'] + ": " + df['Definition']

# %% [markdown]
# #### Generate embeddings

# %%
model = SentenceTransformer('all-MiniLM-L6-v2')  
embeddings = model.encode(df['text'].tolist(), show_progress_bar=True)
# Out:
# Batches:   0%|          | 0/7 [00:00<?, ?it/s]

# %% [markdown]
# #### Clustering based on cosine distance. Only merge topics with a semantic similarity ≥ 0.5 (cosine distance ≤ 0.5).

# %%
clustering = AgglomerativeClustering(
    n_clusters=None,
    distance_threshold=0.5,
    metric='cosine',
    linkage='average'
)
cluster_labels = clustering.fit_predict(embeddings)

# %% [markdown]
# #### Add clustering results back to the original DataFrame

# %%
df['cluster'] = cluster_labels

# %%
grouped = df.groupby('cluster')['text'].apply(list).reset_index()

# %% [markdown]
# #### Visualize

# %%
for i, row in grouped.iterrows():
    print(f"\n🔹 Cluster {row['cluster']} ({len(row['text'])} items):")
    for item in row['text']:
        print(" -", item)
# Out:
# 🔹 Cluster 0 (5 items):
#  - Fear of Failure: Discusses the user's fear of failure as a barrier to implementing behavioral changes.
#  - Fear of Change: Discusses the user's fear or uncertainty about making necessary changes to their behavior or lifestyle.
#  - Fear of Missing Out: Discusses the anxiety that an exciting or interesting event may currently be happening elsewhere, often aroused by posts seen on social media.
#  - Fear of Future Health Problems: Discusses the anxiety about potential health issues in the future due to current unhealthy behaviors.
#  - Fear of Change: Discusses the anxiety or apprehension individuals may feel when considering or facing changes in their lives.
#
# 🔹 Cluster 1 (28 items):
#  - Healthy Eating: Refers to the desire and efforts to improve dietary habits for better health and wellbeing.
#  - Overcoming Temptations: Discusses the struggle to resist unhealthy food choices and the strategies to overcome them.
#  - Meal Planning: Discusses strategies for planning and preparing meals in advance for healthier eating.
#  - Healthy Eating Goals: Refers to the user's desire to improve their diet and eat healthier.
#  - Overcoming Dietary Challenges: Discusses strategies for overcoming challenges related to changing dietary habits, such as planning meals and resisting temptations.
#  - Long-Term Health Goals: Discusses the user's long-term goals for health and wellness, including maintaining a healthy diet and leading an active lifestyle.
#  - Lifestyle Changes: Discusses the user's desire to make long-term lifestyle changes for improved health and well-being.
#  - Healthy Eating: Involves discussions about the desire to improve dietary habits for health and wellness.
#  - Healthy Eating: Involves discussions about dietary habits, the importance of nutrition, and strategies for improving food choices.
#  - Social Life and Healthy Eating: Discusses the challenges of maintaining a healthy diet while participating in social events.
#  - Consequences of Unhealthy Eating: Discusses potential negative outcomes of poor dietary habits, such as weight gain and health problems.
#  - Food Preferences: Discusses the influence of personal food preferences on dietary choices and the challenge of giving up favored unhealthy foods.
#  - Health and Well-being: Discusses the impact of dietary habits and procrastination on physical health and emotional well-being.
#  - Healthy Eating: Discusses the desire to improve dietary habits for better physical health.
#  - Healthy Eating: Discusses the desire to adopt a healthier diet, challenges faced, and strategies to stay motivated, including setting realistic goals and finding healthy alternatives to favorite foods.
#  - Healthy Eating: Discusses the desire to improve diet and nutrition, often with the goal of improving overall health.
#  - Meal Preparation: Discusses the practice of planning and preparing meals in advance, often to support a healthy diet.
#  - Healthy Eating: Discusses the desire to adopt healthier eating habits, reasons for this change, and strategies to achieve it.
#  - Meal Planning: Involves planning meals in advance as a strategy to maintain a healthy diet, especially during stressful times.
#  - Fast Food Consumption: Discusses the desire to reduce fast food consumption as part of a healthier diet.
#  - Healthy Eating: Refers to discussions about dietary habits, nutritional choices, and the desire to improve one's diet for better health and well-being.
#  - Impact of Unhealthy Diet: Discusses the negative effects of poor nutrition on physical health and well-being, including fatigue and susceptibility to diseases.
#  - Lifestyle Changes: Discusses changes in daily routines or habits with the aim of improving personal well-being or achieving specific goals.
#  - Healthy Eating: Discusses the desire to adopt healthier eating habits, challenges in reducing sugar intake, and the goal of weight loss.
#  - Finding Alternatives: Discusses the challenge of finding healthier alternatives that are as satisfying as the current unhealthy choices.
#  - Healthy Eating: Involves discussions about dietary habits, nutritional choices, and the impact of food on health and well-being.
#  - Healthy Eating: Discusses the desire to improve dietary habits, the challenges faced in doing so, and strategies for achieving healthier eating.
#  - Dietary Planning: Refers to the creation and implementation of a diet plan as a strategy for healthier eating.
#
# 🔹 Cluster 2 (6 items):
#  - Weight Loss: Refers to the goal of reducing body weight through dietary changes.
#  - Physical Fitness: Refers to the desire to improve physical health and performance through dietary changes.
#  - Weight Management: Discusses the impact of diet on weight and overall energy levels, and the desire to make changes for better health.
#  - Physical Fitness: Discusses the desire to allocate more time to physical activities like sports or training for a marathon.
#  - Weight Loss: Refers to the goal of losing weight through healthier eating habits.
#  -  Weight Loss: Refers to the goal of losing weight, the motivations behind it, and the steps taken towards achieving it.
#
# 🔹 Cluster 3 (2 items):
#  - Climate Crisis: Refers to concerns about the environmental impacts of human activities and the desire to mitigate these effects.
#  - Environmental Awareness: Discusses the understanding of the impact of personal behaviors on the environment and the desire to mitigate these effects.
#
# 🔹 Cluster 4 (22 items):
#  - Self-Reflection: Discusses the process of introspection to understand one's motives and values.
#  - Self-Assessment: Refers to the process of evaluating one's own interests, abilities, and readiness to make a change.
#  - Self-Confidence: Refers to one's belief in their own abilities to achieve goals or make changes.
#  - Self-Assessment: Involves evaluating one's readiness or confidence in making a behavioral change.
#  - Self-Reflection: Discusses the process of introspection to understand one's motives and values.
#  - Self-Assessment: Involves evaluating one's own readiness, confidence, and progress towards achieving a behavioral change.
#  - Self-Reflection: Discusses the process of introspection to understand one's motives, values, and progress towards a goal.
#  - Self-Confidence: Refers to the individual's belief in their ability to make a desired behavioral change.
#  - Self-Realization: Refers to the desire to fulfill one's potential or achieve personal goals.
#  - Self-confidence: Discusses the impact of achieving personal goals, like completing a half marathon, on self-confidence and self-assurance.
#  - Self-Reflection: Discusses the process of thinking about one's own behaviors, attitudes, and values to understand and improve oneself.
#  - Confidence in Change: Refers to the level of certainty or belief in one's ability to successfully make a desired behavioral change.
#  - Self-Improvement: Refers to the desire to enhance one's skills, knowledge, or personal qualities.
#  - Self-Assessment: Involves evaluating one's readiness and confidence to make a behavioral change on a scale from 0 to 10.
#  - Self-Reflection: Refers to the process of reflecting on one's behavior, motives, and values to understand and facilitate behavioral change.
#  - Self-Reflection: Involves introspective discussions about personal attitudes, values, and experiences related to behavioral change.
#  - Self-Assessment: Refers to the process of evaluating one's own behavior, progress, and challenges in the journey towards behavioral change.
#  - Self-Efficacy: Refers to an individual's belief in their ability to succeed in specific situations or accomplish a task.
#  - Self-Reflection: Refers to the process of thinking about one's own behaviors, beliefs, and motivations to gain self-awareness and promote personal growth.
#  - Self-Perception: Discusses how individuals perceive their own behaviors, characteristics, and abilities.
#  - Self-Improvement: Discusses the process of making changes to one's knowledge, skills, habits, or behaviors in order to enhance personal development and achieve desired goals.
#  - Self-Assessment: Refers to the process of evaluating one's own behaviors, attitudes, and values in relation to desired behavioral changes.
#
# 🔹 Cluster 5 (4 items):
#  - Emotional Well-being: Refers to the importance of feeling comfortable and happy as a result of positive lifestyle changes.
#  - Personal Well-being: Refers to the impact of behavioral changes on personal happiness, satisfaction, and overall health.
#  - Personal Fulfillment: Discusses the pursuit of activities that bring satisfaction and happiness, often in the context of achieving a healthier, more balanced lifestyle.
#  - Leisure Activities: Discusses the importance of recreational activities for personal fulfillment and well-being.
#
# 🔹 Cluster 6 (19 items):
#  - Behavioral Change: Discusses the process of altering or modifying one's actions, habits, or patterns for improvement.
#  - Habit Formation: Discusses the process of developing new habits or routines for behavioral change.
#  - Resistance to Change: Discusses the challenges or resistance faced when trying to implement new behaviors or habits.
#  - Behavioral Change: Discusses the process of altering one's actions, habits, or patterns to achieve a desired goal or outcome.
#  - Change Resistance: Discusses the challenges and barriers to implementing desired changes.
#  - Readiness for Change: Discusses the user's level of readiness and motivation to make a behavioral change.
#  - Behavioral Change: Discusses the desire and process of altering one's actions or habits
#  - Behavioral Change: Discusses the process of altering patterns of behavior, often to improve personal health, productivity, or well-being.
#  - Behavioral Change Strategies: Discusses various strategies and steps to facilitate behavioral change, such as setting small goals, rewarding oneself, and seeking external support.
#  - Motivation for Change: Discusses the need for motivation in implementing behavioral changes, including setting up meal plans or visualizing goals.
#  - Behavioral Change: Discusses the process of altering one's behaviors or habits, often to improve personal wellbeing or achieve a specific goal.
#  - Behavioral Change: Refers to the process of changing one's behavior, the challenges faced, and strategies to overcome them.
#  - Habit Formation: Discusses the difficulty of breaking bad habits and forming new ones as part of behavioral change.
#  - Behavioral Change: Discusses the process of identifying, understanding, and modifying behaviors, often with the aim of improving personal well-being or achieving specific goals.
#  - Motivation for Change: Explores the individual's motivation level to implement a behavioral change, including their readiness and interest in making the change.
#  - Strategy Implementation: Discusses the practical steps and strategies to implement in order to achieve a desired behavioral change.
#  - Habit Formation: Discusses the formation and impact of long-term habits, such as evening routines involving sweets.
#  - Behavioral Change: Discusses the process of identifying, understanding, and modifying behaviors, often with the aim of improving personal well-being or achieving specific goals.
#  - Behavioral Change: Covers the overall theme of wanting to change certain behaviors, the motivations behind these changes, and the strategies used to achieve them.
#
# 🔹 Cluster 7 (26 items):
#  - Procrastination: Discusses the habit of delaying or postponing tasks and the desire to overcome this behavior.
#  - Procrastination: Discusses the act of delaying or postponing tasks, often leading to inefficiency and dissatisfaction.
#  - Procrastination Reduction: Refers to the user's goal to reduce procrastination and improve productivity.
#  - Analytical Paralysis: Discusses the user's tendency to overthink tasks, leading to procrastination and inaction.
#  - Procrastination: Discusses the habit of delaying tasks and the desire to improve productivity.
#  - Procrastination: Refers to the act of delaying or postponing tasks, its impact on productivity, and methods to overcome it.
#  - Benefits of Overcoming Procrastination: Discusses the positive outcomes of reducing procrastination, such as increased productivity and satisfaction.
#  - Task Management: Discusses strategies for managing and prioritizing tasks to increase productivity and reduce procrastination.
#  - Discipline and Productivity: Discusses the relationship between self-discipline, procrastination, and productivity.
#  - Procrastination: Discusses the desire to reduce procrastination in order to increase productivity and achieve personal or professional goals.
#  - Digital Distractions: Discusses the role of digital platforms, such as social media and other apps, in contributing to procrastination.
#  - Guilt and Rest: Discusses the feelings of guilt associated with taking breaks or resting, often perceived as procrastination.
#  - Procrastination: Covers the struggle with delaying or postponing tasks, its impact on productivity, and strategies to manage it.
#  - Procrastination: Discusses the desire to delay or postpone tasks, often leading to decreased productivity and efficiency.
#  - Procrastination: Discusses the desire to reduce procrastination in order to increase productivity and effectively manage time.
#  - Productivity: Refers to the desire to increase productivity by reducing procrastination and effectively managing time.
#  - Procrastination: Refers to the act of delaying or postponing tasks, and the desire to reduce this behavior to improve productivity and efficiency.
#  - Impact of Procrastination: Discusses the negative effects of procrastination on personal efficiency, time management, and the achievement of goals.
#  - Prioritization: Discusses the process of determining the order and importance of tasks to improve productivity and reduce procrastination.
#  - Focus and Concentration: Discusses the importance of maintaining focus and concentration in order to reduce procrastination and improve productivity.
#  - Procrastination: Discusses the desire to reduce procrastination, strategies to overcome it, and the impact of procrastination on work productivity and personal satisfaction.
#  - Distractions: Discusses the role of distractions, particularly mobile phones, in hindering productivity and contributing to procrastination.
#  - Procrastination: Refers to the act of delaying or postponing tasks, often leading to inefficiency and stress.
#  - Social Media Distraction: Refers to the impact of social media on attention and productivity, often leading to procrastination.
#  - Procrastination: Covers the desire to reduce procrastination, the impact of procrastination on work efficiency, and strategies to overcome it.
#  - Guilt and Emotional Response: Covers feelings of guilt and emotional discomfort as a result of certain behaviors, such as procrastination.
#
# 🔹 Cluster 8 (2 items):
#  - Task Prioritization: Discusses the process of ranking tasks based on their importance or urgency.
#  - Task Management: Discusses strategies for managing and completing accumulated tasks to reduce feelings of overwhelm.
#
# 🔹 Cluster 9 (12 items):
#  - Goal Setting: Involves the process of defining and planning steps to achieve specific objectives.
#  - Goal Setting: Refers to the process of defining and prioritizing objectives to facilitate behavioral change.
#  - Goal Setting: Discusses the process of setting clear and achievable goals as a strategy for behavioral change.
#  - Goal Setting: Involves the process of defining and planning steps to achieve specific objectives.
#  - Goal Setting: Discusses the importance of setting small, achievable goals as a strategy for behavioral change.
#  - Goal Setting: Discusses the importance of setting realistic and achievable goals as a part of behavioral change strategies.
#  - Goal Setting: Discusses the process of defining and working towards specific, achievable objectives.
#  - Goal Setting: Involves setting clear and achievable goals as a strategy to motivate behavioral change.
#  - Goal Setting: Discusses the process of defining and planning steps to achieve specific, personal objectives.
#  - Goal Setting: Involves discussions about setting small, achievable goals as a strategy to combat procrastination and improve productivity.
#  - Goal Setting: Discusses the process of identifying specific, measurable, achievable, relevant, and time-bound (SMART) goals to facilitate behavior change.
#  - Goal Setting: Discusses the process of setting specific, achievable goals as a strategy for behavioral change.
#
# 🔹 Cluster 10 (3 items):
#  - Academic Success: Refers to the desire to improve study habits and grades in order to achieve a higher degree.
#  - Study Habits: Discusses strategies and routines for effective learning and academic success.
#  - Learning Strategies: Discusses various methods and techniques used to enhance learning and improve academic performance.
#
# 🔹 Cluster 11 (14 items):
#  - Motivation and Confidence: Discusses the level of interest, motivation, and confidence in making a behavioral change.
#  - Motivation: Involves discussions about the drive or desire to achieve a goal or make a change.
#  - Motivation: Discusses the level of enthusiasm or drive towards achieving a specific goal.
#  - Motivation: Discusses the level of interest or enthusiasm towards making a behavioral change, and factors influencing it.
#  - Reward System: Discusses the idea of rewarding oneself after achieving a task as a motivation booster.
#  - Motivation: Discusses the driving force behind wanting to make a behavioral change, often linked to personal or professional success.
#  - Motivation: Refers to the drive or desire to achieve a goal or make a behavioral change, often influenced by personal values and experiences.
#  - Reward System: Discusses the use of rewards or incentives to motivate desired behaviors or achieve goals.
#  - Motivation: Refers to the level of readiness and enthusiasm towards making a behavioral change, and strategies to increase motivation.
#  - Motivation and Confidence: Involves discussions about the level of interest, readiness, and confidence in making a behavioral change.
#  - Self-Reward: Discusses the idea of rewarding oneself as a motivational strategy to achieve small goals and make progress.
#  - Motivation: Discusses the psychological factors that drive individuals to initiate, continue, or cease certain behaviors.
#  - Reward Systems: Discusses the use of rewards or incentives to motivate behavior change and achieve personal goals.
#  - Motivation and Confidence: Covers the level of motivation and confidence in making behavioral changes, and the factors influencing these feelings.
#
# 🔹 Cluster 12 (4 items):
#  - Stress Management: Discusses the desire to reduce stress and achieve inner peace through behavioral changes.
#  - Stress Management: Discusses strategies for dealing with stress, particularly during periods of significant change or upheaval.
#  - Stress Management: Discusses the impact of stress on behavior and strategies to manage it.
#  - Stress Management: Discusses the impact of stress on the ability to maintain healthy eating habits and strategies to manage it.
#
# 🔹 Cluster 13 (2 items):
#  - Distraction Management: Discusses strategies to manage distractions, such as creating a quiet, disturbance-free environment for focused work.
#  - Distractions: Discusses elements or activities that divert attention away from the task at hand, such as mobile phones or other enjoyable activities.
#
# 🔹 Cluster 14 (3 items):
#  - Support System: Refers to seeking help or support from friends or family in achieving a goal.
#  - Seeking Help: Discusses the idea of seeking help from others as a strategy to overcome challenges and achieve behavioral change.
#  - Peer Support: Discusses the role of social support in motivating and sustaining behavior change.
#
# 🔹 Cluster 15 (9 items):
#  - Productivity: Refers to the desire to increase efficiency in work or personal tasks to achieve more in less time.
#  - ADHD and Productivity: Discusses the impact of Attention Deficit Hyperactivity Disorder (ADHD) on work efficiency and strategies to manage it.
#  - Use of Technology for Productivity: Discusses the use of tools and techniques like To-Do lists, planners, noise-cancelling headphones, and the Pomodoro technique to enhance productivity.
#  - Productivity: Involves discussions about improving efficiency in work or daily tasks.
#  - Productivity: Involves discussions about improving work efficiency, often through reducing distractions or implementing new strategies.
#  - Career Advancement: Discusses the desire to improve productivity and concentration to achieve career goals.
#  - Productivity: Refers to the ability to accomplish tasks efficiently and effectively, often in a work or academic context.
#  - Role of Technology in Productivity: Discusses the impact of technology, particularly mobile phones, on work efficiency and productivity.
#  - Work Efficiency: Discusses the importance of being more productive and efficient at work, and the steps taken to achieve this.
#
# 🔹 Cluster 16 (1 items):
#  - Emotional Connection to Food: Discusses the emotional aspect of eating, particularly the use of sweets as a reward or stress reliever.
#
# 🔹 Cluster 17 (4 items):
#  - Coping with Setbacks: Discusses the normalcy of experiencing setbacks in the process of behavioral change and strategies to deal with them.
#  - Coping Strategies: Discusses methods to handle challenging situations or obstacles in achieving goals.
#  - Overcoming Obstacles: Addresses the challenges faced when trying to make behavioral changes and strategies to overcome them, such as using a bike in bad weather.
#  - Overcoming Challenges: Discusses strategies and experiences related to overcoming obstacles or difficulties in the process of behavioral change.
#
# 🔹 Cluster 18 (3 items):
#  - Transportation Choices: Discusses the impact of transportation decisions, such as car usage, on personal sustainability goals.
#  - Public Transport: Discusses the use of public transport as a more sustainable alternative to personal vehicles.
#  - Physical Limitations: Discusses the impact of physical restrictions on the ability to make certain behavioral changes, such as using sustainable transport options.
#
# 🔹 Cluster 19 (1 items):
#  - Family and Social Relationships: Discusses the importance of spending quality time with family and friends, and the impact of behavioral changes on these relationships.
#
# 🔹 Cluster 20 (2 items):
#  - Personal Values: Discusses the underlying beliefs or principles that guide an individual's behavior.
#  - Personal Values: Discusses the principles or standards of behavior that individuals consider important in their lives.
#
# 🔹 Cluster 21 (8 items):
#  - Time Management: Discusses strategies to use time more effectively and efficiently.
#  - Time Management: Discusses strategies for effectively managing one's time to increase productivity and reduce procrastination.
#  - Time Management Techniques: Discusses the use of techniques such as the Pomodoro technique to manage time and reduce procrastination.
#  - Time Management: Discusses the use of techniques like the Pomodoro method to manage time effectively and reduce procrastination.
#  - Time Management Techniques: Discusses strategies for managing time effectively, such as the Pomodoro technique or setting specific working hours.
#  - Time Management: Discusses the importance of effectively managing one's time to achieve goals, reduce stress, and improve overall life satisfaction.
#  - Time Management: Refers to the process of organizing and planning how to divide your time between specific activities to increase efficiency and productivity.
#  - Time Management: Discusses the challenges of managing time effectively, particularly in relation to work commitments and personal goals.
#
# 🔹 Cluster 22 (3 items):
#  - Seeking External Support: Discusses the user's need for external support, such as apps or diet plans, to facilitate behavioral changes.
#  - External Support: Discusses the role of external help, such as someone cooking healthier meals, in facilitating dietary changes.
#  - Professional Support: Discusses the potential need for professional help, such as a nutritionist or coach, to facilitate behavioral change.
#
# 🔹 Cluster 23 (4 items):
#  - Chatbot Interaction: Refers to the dialogue and interaction with a motivational chatbot for behavioral change.
#  - Motivational Chatbot Interaction: Discusses the interaction between the user and a motivational chatbot designed to help with behavioral changes.
#  - Self-Reflection: Discusses the process of self-reflection facilitated by the chatbot, helping the user understand their motives and values.
#  - Motivational Chatbot Interaction: Discusses the role of a motivational chatbot in facilitating self-reflection and planning for behavioral change.
#
# 🔹 Cluster 24 (1 items):
#  - Comparison with Others: Discusses the tendency to compare one's progress or achievements with those of others, often leading to feelings of frustration or inadequacy.
#
# 🔹 Cluster 25 (1 items):
#  - Second-Hand Shopping: Discusses the practice of buying used items as a more sustainable alternative to buying new.
#
# 🔹 Cluster 26 (1 items):
#  - Environment Design: Discusses the process of arranging or modifying one's physical surroundings to support desired behaviors or goals.
#
# 🔹 Cluster 27 (1 items):
#  - Life Purpose: Discusses existential questions about the meaning and purpose of life.
#
# 🔹 Cluster 28 (1 items):
#  - Organic Products: Discusses the preference for foods produced without the use of synthetic pesticides, fertilizers, or genetically modified organisms.
#
# 🔹 Cluster 29 (1 items):
#  - Discipline: Discusses the practice of training oneself to follow rules or a code of behavior, often to achieve a personal goal.
#
# 🔹 Cluster 30 (1 items):
#  - Household Cooperation: Discusses the challenges and strategies of implementing changes within a shared living environment.
#
# 🔹 Cluster 31 (1 items):
#  - Market Saturation: Discusses the challenges of finding a unique and profitable niche in a crowded market.
#
# 🔹 Cluster 32 (1 items):
#  - Learning and Development: Refers to the process of acquiring new knowledge or skills, often for personal or professional growth.
#
# 🔹 Cluster 33 (1 items):
#  - Health Concerns: Involves discussions about health issues such as overweight and high blood pressure, and the desire to manage them.
#
# 🔹 Cluster 34 (1 items):
#  - Creative Interests: Refers to personal hobbies or passions, such as painting or reading, and their potential to become a career.
#
# 🔹 Cluster 35 (1 items):
#  - Gradual Change: Discusses the strategy of implementing changes slowly and steadily, rather than making drastic changes all at once.
#
# 🔹 Cluster 36 (1 items):
#  - Financial Stability: Discusses the importance of finding a profitable passion or career path.
#
# 🔹 Cluster 37 (1 items):
#  - Meat Consumption: Refers to the environmental and health impacts of consuming meat and the desire to reduce or eliminate it from one's diet.
#
# 🔹 Cluster 38 (1 items):
#  - Morning Routine: Refers to the desire to improve productivity and efficiency in the morning hours.
#
# 🔹 Cluster 39 (1 items):
#  - Fast Fashion: Discusses the environmental impact of the fashion industry and the desire to make more sustainable clothing choices.
#
# 🔹 Cluster 40 (1 items):
#  - Comfort Zone: Discusses the concept of stepping out of one's comfort zone to facilitate change.
#
# 🔹 Cluster 41 (1 items):
#  - Use of To-Do Lists: Discusses the user's plan to use to-do lists as a strategy to reduce procrastination and increase organization.
#
# 🔹 Cluster 42 (1 items):
#  - Risk-Taking: Refers to the willingness to take chances in order to achieve personal or professional goals.
#
# 🔹 Cluster 43 (1 items):
#  - Patience: Refers to the willingness to tolerate delay or adversity in the process of achieving a goal.
#
# 🔹 Cluster 44 (1 items):
#  - Work-Life Balance: Discusses the struggle to balance professional responsibilities with personal needs and leisure activities.
#
# 🔹 Cluster 45 (1 items):
#  - Waste Management: Discusses the role of waste separation in living more sustainably.
#
# 🔹 Cluster 46 (5 items):
#  - Sustainability: Refers to the practice of living in a way that reduces one's environmental impact for the benefit of the planet and future generations.
#  - Sustainable Living: Discusses the desire to adopt environmentally friendly habits for the betterment of the planet.
#  - Sustainable Living: Discusses the desire and strategies to adopt a lifestyle that reduces one's environmental impact, including driving less and buying regional products.
#  - Sustainable Living: Discusses the practice of reducing one's use of natural resources to protect the environment for future generations.
#  - Sustainable Living: Refers to the desire to live more sustainably, the reasons behind this choice, and the challenges faced in implementing sustainable practices.
#
# 🔹 Cluster 47 (1 items):
#  - Financial Gain: Refers to the desire to increase income or financial rewards through improved productivity.
#
# 🔹 Cluster 48 (1 items):
#  - Social Media Influence: Refers to the impact of social media on behavior and decision-making.
#
# 🔹 Cluster 49 (1 items):
#  - Frustration: Discusses feelings of dissatisfaction or annoyance, often resulting from unmet expectations or goals.
#
# 🔹 Cluster 50 (1 items):
#  - Emotional Response: Discusses the emotional reactions or feelings towards certain tasks or changes.

# %% [markdown]
# #### Select one representative topic per cluster (first item in each cluster)

# %%
representatives = df.groupby('cluster').first().reset_index()
representatives = representatives[['cluster', 'Topics', 'Definition']]

# %% [markdown]
# #### We got 51 representative topics

# %%
len(representatives)
# Out:
# 51

# %% [markdown]
# #### Save the representative topics

# %%
representatives.to_csv("topics_after_deduplication.csv", index=False)
